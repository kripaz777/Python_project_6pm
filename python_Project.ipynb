# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup('https://www.worldometers.info/coronavirus/', 'html.parser')
soup = requests.get(url)
soup = BeautifulSoup(soup.text, "lxml")
table_code = soup.table
# Out:
# <ipython-input-1-22f41612e60e>:3: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   url = BeautifulSoup('https://www.worldometers.info/coronavirus/', 'html.parser')

# %%
tr_tags = table_code.find_all('tr')
# tr_tags

# %%
data = []
for i in tr_tags:
  y = i.text.split('\n')
  if y[1] != "":
    data.append(y[1:])

# %%
# data

# %%
import csv
file = open('data.csv','w')
x = csv.writer(file)
x.writerows(data)
file.close()

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#        #   Country,Other   TotalCases NewCases  \
# 0      1             USA  109,746,861      NaN
# 1      2           India   45,003,341      NaN
# 2      3          France   40,138,560      NaN
# 3      4         Germany   38,696,556   +7,922
# 4      5          Brazil   38,106,633      NaN
# ..   ...             ...          ...      ...
# 226  227         Tokelau           80      NaN
# 227  228    Vatican City           29      NaN
# 228  229  Western Sahara           10      NaN
# 229  230      MS Zaandam            9      NaN
# 230  231           China      503,302      NaN
#
#                                    TotalDeaths  NewDeaths TotalRecovered  \
# 0    1,188,692                                        NaN    107,610,037
# 1      533,307                                        NaN            NaN
# 2      167,642                                        NaN     39,970,918
# 3      178,943                                       84.0     38,240,600
# ...

# %%
# !pip install plotly==5.18.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 82.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ...

# %%
df['TotalCases'][0:10] = list(map(lambda x:int(x.replace(',','')), df['TotalCases'][0:10]))
df['TotalDeaths'][0:10] = list(map(lambda x:int(x.replace(',','')), df['TotalDeaths'][0:10]))
df
# Out:
# <ipython-input-8-272452f8d2e4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalCases'][0:10] = list(map(lambda x:int(x.replace(',','')), df['TotalCases'][0:10]))
# <ipython-input-8-272452f8d2e4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalDeaths'][0:10] = list(map(lambda x:int(x.replace(',','')), df['TotalDeaths'][0:10]))
#        #   Country,Other TotalCases NewCases  \
# 0      1             USA  109746861      NaN
# 1      2           India   45003341      NaN
# 2      3          France   40138560      NaN
# 3      4         Germany   38696556   +7,922
# ...

# %%
TotalCases = list(map(lambda x:int(x.replace(',','')), df['TotalCases'][0:10]))
TotalDeaths = list(map(lambda x:int(x.replace(',','')), df['TotalDeaths'][0:10]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-c6a95d4b31a1> in <cell line: 1>()
# ----> 1 TotalCases = list(map(lambda x:int(x.replace(',','')), df['TotalCases'][0:10]))
#       2 TotalDeaths = list(map(lambda x:int(x.replace(',','')), df['TotalDeaths'][0:10]))
#
# <ipython-input-9-c6a95d4b31a1> in <lambda>(x)
# ----> 1 TotalCases = list(map(lambda x:int(x.replace(',','')), df['TotalCases'][0:10]))
#       2 TotalDeaths = list(map(lambda x:int(x.replace(',','')), df['TotalDeaths'][0:10]))
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
import plotly.express as px
fig = px.bar(df.iloc[0:20], x='Country,Other', y='TotalCases')
fig.show()

# %%
import plotly.express as px
fig = px.bar(df.iloc[0:20], x='Country,Other', y='TotalDeaths')
fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[
    go.Bar(name='TotalCases', x=df['Country,Other'][0:10], y=TotalCases),
    go.Bar(name='TotalDeaths', x=df['Country,Other'][0:10], y=TotalDeaths)
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()
